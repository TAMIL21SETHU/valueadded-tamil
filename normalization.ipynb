# %% [markdown]
# <a href="https://colab.research.google.com/github/TAMIL21SETHU/valueadded-tamil/blob/main/normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import  Normalizer

# %%
Normalization_df = pd.DataFrame({'x':np.random.randint(-100,100,1000),
                              'y':np.random.randint(-80,80,1000),
                              'z':np.random.randint(-150,150,1000)})

# %%
Normalization_df
# Out:
#       x   y    z
# 0    -4  10   44
# 1   -45 -12  120
# 2   -26  -6  -21
# 3    69  42   51
# 4    82  55   39
# ..   ..  ..  ...
# 995  39 -78  121
# 996 -75   2  123
# 997 -47 -39  -88
# 998  54  41 -128
# 999 -90 -45   79
#
# [1000 rows x 3 columns]

# %%
from matplotlib.figure import projections
ax = plt.axes(projection='3d')

ax.scatter3D(Normalization_df.x,Normalization_df.y,
             Normalization_df.z,)

plt.figure()

# %%
from sklearn.preprocessing import Normalizer

# %%
nol= Normalizer()

# %%
Normalization_df = nol.fit_transform(Normalization_df)

# %%
Normalization_df
# Out:
# array([[-0.08830216,  0.22075539,  0.97132373],
#        [-0.34959432, -0.09322515,  0.93225151],
#        [-0.76570008, -0.17670002, -0.61845007],
#        ...,
#        [-0.43877355, -0.36408869, -0.82153345],
#        [ 0.37280409,  0.28305496, -0.88368377],
#        [-0.70351156, -0.35175578,  0.61752681]])

# %%
Normalization_df=pd.DataFrame(Normalization_df,columns=['x','y','z'])
Normalization_df
# Out:
#             x         y         z
# 0   -0.088302  0.220755  0.971324
# 1   -0.349594 -0.093225  0.932252
# 2   -0.765700 -0.176700 -0.618450
# 3    0.722285  0.439652  0.533863
# 4    0.772417  0.518085  0.367369
# ..        ...       ...       ...
# 995  0.261480 -0.522960  0.811259
# 996 -0.520557  0.013882  0.853714
# 997 -0.438774 -0.364089 -0.821533
# 998  0.372804  0.283055 -0.883684
# 999 -0.703512 -0.351756  0.617527
#
# [1000 rows x 3 columns]

# %%
ax = plt.axes(projection='3d')

ax.scatter3D(Normalization_df.x,Normalization_df.y,
             Normalization_df.z,)

plt.figure()

# %%
data={'first score':[100,90,np.nan,95],
      'second score':[30,45,56,np.nan],
      'third score':[np.nan,40,80,98]}

# %%
data
# Out:
# {'first score': [100, 90, nan, 95],
#  'second score': [30, 45, 56, nan],
#  'third score': [nan, 40, 80, 98]}

# %%
var=pd.DataFrame(data)

# %%
var
# Out:
#    first score  second score  third score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
var.isnull()
var.isnull().sum()
# Out:
# first score     1
# second score    1
# third score     1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer.fit(var)
imputer.transform(var)
# Out:
# array([[100.        ,  30.        ,  72.66666667],
#        [ 90.        ,  45.        ,  40.        ],
#        [ 95.        ,  56.        ,  80.        ],
#        [ 95.        ,  43.66666667,  98.        ]])
